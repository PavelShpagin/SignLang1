# %%
################################################
### using filtered data

# %%
import pickle
with open('shaped.pickle', 'rb') as f:
    ab = pickle.load(f)

# %%
ab.shape
# Out:
# (297, 1200)

# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
#from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble

import numpy #,  string #pandas, xgboost, textblob,
#from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras import layers, models, optimizers

# %%
import tensorflow as tf
tf. __version__
# Out:
# '2.15.0'

# %%
# Define models:

def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_y)

def train_model2(classifier, feature_vector_train, label, feature_vector_valid, valid_Y, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    
    return metrics.accuracy_score(predictions, valid_Y)

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
import numpy as np
from scipy.sparse import csr_matrix

from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import time
import warnings

import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

import scipy

# %%
y_ = np.ones(len(ab))

# %%
start_time = time.time()
#a = np.reshape(np.array(tempvar),(297*20,60))

#base parameters
default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10, #maybe more
                'n_clusters': 4, #3 is actual number
                'min_samples': 20,
                'xi': 0.05,
                'min_cluster_size': 0.1}
    
params = default_base.copy()

pca = TruncatedSVD(n_components=10)
pca.fit(ab)
#csr_matrix(
transformed_ = pca.transform(ab)
end_time = time.time()
end_time-start_time
# Out:
# 0.07350277900695801

# %%
#X_embedded2 = X_embedded

# %%
#X_embedded = transformed_

# %%
start_time = time.time()
#X_embedded = TSNE(n_components=2).fit_transform(transformed_)
X_embedded = transformed_
end_time = time.time()
end_time-start_time
# Out:
# 6.151199340820312e-05

# %%
# ============
# Create cluster objects
# ============

    

two_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])

clustering_algorithms = (
        ('MBatchKMeans', two_means),
)

plot_num = 1

# %%
for name, algorithm in clustering_algorithms:
        
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the " +
                "connectivity matrix is [0-9]{1,2}" +
                " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning)
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding" +
                " may not work as expected.",
                category=UserWarning)
            algorithm.fit(X_embedded)

        
        
        t1 = time.time()
        
        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X_embedded)

        plt.subplot(1, len(clustering_algorithms), plot_num)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])

        
        plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())

        plot_num += 1
        
        # stop, plot only one image 
        break

#plt.show()
t1-t0
# Out:
# /home/vlads/miniconda3/envs/tf2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1934: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)
# 0.07616996765136719

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(y_pred) + 1))))

plt.figure(figsize=(6, 6))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, c=colors[y_pred])
plt.colorbar()
plt.show()

# %%
y_pred.shape
# Out:
# (297,)

# %%
#optional classifiers to choose
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
# ab (297x1200)!

# %%
start_time = time.time()
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(X_embedded, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.0008895397186279297

# %%
import numpy as np
#import pandas as pd
import os

import tensorflow as tf
#import tensorflow_addons as tfa #none
from tensorflow.keras import layers 

import matplotlib.pyplot as plt
from IPython import display
from IPython.display import clear_output

import glob
#import imageio
import time
import IPython.display as ipd

#AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# Shallow Neural Networks
# model nx100xn

import numpy as np
import scipy.sparse
import tensorflow as tf

import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
import tensorflow.keras as keras
from tensorflow.keras import backend as K

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model

# %%
def create_dense_ae():
    # Розмірність кодованого простору 
    hidden_dim = 60
    encoding_dim = 2
    
    # Кодувальник
    input = Input(shape=(10*1, )) # 10*1,  - розмірність вхідного шару
    # Додатковий шар для кодування вхідного представлення
    flat = Flatten()(input)
    
    hidden = Dense(hidden_dim, activation='relu')(flat)
    hidden2 = Dense(hidden_dim, activation='relu')(hidden)
    # Приховане подання кодувальника
    encoded = Dense(encoding_dim, activation='relu')(hidden2)
    
    # Декодувальник
    # Аналогічним чином, але послідовність шарів протилежна кодувальнику
    input_encoded = Input(shape=(encoding_dim,))
    hidden_encoded = Dense(hidden_dim, activation='sigmoid')(input_encoded)
    hidden_encoded2 = Dense(hidden_dim, activation='sigmoid')(hidden_encoded)
    
    flat_decoded = Dense(10*1, activation='sigmoid')(hidden_encoded2)
    decoded = Reshape((10*1, ))(flat_decoded)

    # Таким чином можна подати окремо модель як для кодувальника так і декодувальника
    # Або подавати шари окермо
    encoder = Model(input, encoded, name="encoder")
    decoder = Model(input_encoded, decoded, name="decoder")
    autoencoder = Model(input, decoder(encoder(input)), name="autoencoder")
    return encoder, decoder, autoencoder

# %%
# перелік наявних пристроїв (Ubuntu)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
with tf.device("/device:GPU:0"): 
    encoder, decoder, autoencoder = create_dense_ae()
    autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
# якщо все гаразд, у консолі Conda має бути подібний текст:
# tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with XXXX MB memory:  -> device: 0, name: __YOUR GPU___, pci bus id: 0000:08:00.0, compute capability: Y.W

# %%
# якщо немає відеокарти як такої (наприклад, якщо є процесор з ARM архітектурою без виділеного відеоядра), можливо написати і так:

# %%
#with tf.device("/device:CPU:0"):
#    encoder, decoder, autoencoder = create_dense_ae()
#    autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
import tensorflow as tf
tf.get_logger().setLevel('INFO')

# %%
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 10)]              0
#
#  encoder (Functional)        (None, 2)                 4442
#
#  decoder (Functional)        (None, 10)                4450
#
# =================================================================
# Total params: 8892 (34.73 KB)
# Trainable params: 8892 (34.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
with tf.device("/device:GPU:0"):    
    start_time = time.time()
    autoencoder.fit(train_x, train_x,
        epochs=500,
        batch_size=50,
        shuffle=True,
        validation_data=(valid_x, valid_x))
    end_time = time.time()
    #end_time-start_time
# Out:
# Epoch 1/500
# 5/5 [==============================] - 0s 15ms/step - loss: -14.3233 - accuracy: 0.6396 - val_loss: -14.3836 - val_accuracy: 0.6133
# Epoch 2/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3288 - accuracy: 0.6216 - val_loss: -14.3866 - val_accuracy: 0.6533
# Epoch 3/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3338 - accuracy: 0.6396 - val_loss: -14.3905 - val_accuracy: 0.6533
# Epoch 4/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3378 - accuracy: 0.6396 - val_loss: -14.3962 - val_accuracy: 0.6000
# Epoch 5/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3429 - accuracy: 0.6216 - val_loss: -14.3988 - val_accuracy: 0.6533
# Epoch 6/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3472 - accuracy: 0.6396 - val_loss: -14.4043 - val_accuracy: 0.6533
# Epoch 7/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3515 - accuracy: 0.6396 - val_loss: -14.4082 - val_accuracy: 0.6533
# Epoch 8/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3561 - accuracy: 0.6306 - val_loss: -14.4163 - val_accuracy: 0.6533
# Epoch 9/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3613 - accuracy: 0.6306 - val_loss: -14.4212 - val_accuracy: 0.6533
# Epoch 10/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3653 - accuracy: 0.6396 - val_loss: -14.4247 - val_accuracy: 0.6133
# Epoch 11/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3696 - accuracy: 0.6306 - val_loss: -14.4274 - val_accuracy: 0.6533
# Epoch 12/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3738 - accuracy: 0.6396 - val_loss: -14.4351 - val_accuracy: 0.5733
# Epoch 13/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3783 - accuracy: 0.6081 - val_loss: -14.4364 - val_accuracy: 0.6533
# Epoch 14/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3811 - accuracy: 0.6396 - val_loss: -14.4402 - val_accuracy: 0.6533
# Epoch 15/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3863 - accuracy: 0.6396 - val_loss: -14.4471 - val_accuracy: 0.6533
# Epoch 16/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3913 - accuracy: 0.6396 - val_loss: -14.4534 - val_accuracy: 0.6533
# Epoch 17/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.3957 - accuracy: 0.6396 - val_loss: -14.4576 - val_accuracy: 0.5867
# Epoch 18/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.4017 - accuracy: 0.6126 - val_loss: -14.4627 - val_accuracy: 0.6000
# Epoch 19/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.4061 - accuracy: 0.6216 - val_loss: -14.4623 - val_accuracy: 0.6533
# Epoch 20/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.4084 - accuracy: 0.6396 - val_loss: -14.4626 - val_accuracy: 0.6533
# Epoch 21/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.4139 - accuracy: 0.6216 - val_loss: -14.4688 - val_accuracy: 0.5733
# Epoch 22/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.4205 - accuracy: 0.6126 - val_loss: -14.4759 - val_accuracy: 0.6533
# Epoch 23/500
# 5/5 [==============================] - 0s 6ms/step - loss: -14.
500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.4911 - accuracy: 0.6396 - val_loss: -15.3546 - val_accuracy: 0.6667
# Epoch 237/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.4942 - accuracy: 0.6532 - val_loss: -15.3575 - val_accuracy: 0.6667
# Epoch 238/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.5009 - accuracy: 0.6532 - val_loss: -15.3729 - val_accuracy: 0.6533
# Epoch 239/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.5048 - accuracy: 0.6396 - val_loss: -15.3681 - val_accuracy: 0.6533
# Epoch 240/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5120 - accuracy: 0.6486 - val_loss: -15.3751 - val_accuracy: 0.6533
# Epoch 241/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5164 - accuracy: 0.6396 - val_loss: -15.3739 - val_accuracy: 0.6667
# Epoch 242/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5219 - accuracy: 0.6532 - val_loss: -15.3682 - val_accuracy: 0.6533
# Epoch 243/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5267 - accuracy: 0.6396 - val_loss: -15.3810 - val_accuracy: 0.6667
# Epoch 244/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.5329 - accuracy: 0.6532 - val_loss: -15.3818 - val_accuracy: 0.6667
# Epoch 245/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5414 - accuracy: 0.6532 - val_loss: -15.3981 - val_accuracy: 0.6667
# Epoch 246/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5500 - accuracy: 0.6532 - val_loss: -15.3963 - val_accuracy: 0.6667
# Epoch 247/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5526 - accuracy: 0.6532 - val_loss: -15.4035 - val_accuracy: 0.6667
# Epoch 248/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5586 - accuracy: 0.6532 - val_loss: -15.4091 - val_accuracy: 0.6667
# Epoch 249/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5647 - accuracy: 0.6532 - val_loss: -15.4096 - val_accuracy: 0.6533
# Epoch 250/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5680 - accuracy: 0.6396 - val_loss: -15.4178 - val_accuracy: 0.6667
# Epoch 251/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5737 - accuracy: 0.6532 - val_loss: -15.4250 - val_accuracy: 0.6667
# Epoch 252/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5781 - accuracy: 0.6532 - val_loss: -15.4295 - val_accuracy: 0.6667
# Epoch 253/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5846 - accuracy: 0.6532 - val_loss: -15.4327 - val_accuracy: 0.6667
# Epoch 254/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.5891 - accuracy: 0.6532 - val_loss: -15.4367 - val_accuracy: 0.6667
# Epoch 255/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5957 - accuracy: 0.6441 - val_loss: -15.4389 - val_accuracy: 0.6667
# Epoch 256/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.5992 - accuracy: 0.6532 - val_loss: -15.4453 - val_accuracy: 0.6533
# Epoch 257/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6026 - accuracy: 0.6396 - val_loss: -15.4478 - val_accuracy: 0.6667
# Epoch 258/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6081 - accuracy: 0.6532 - val_loss: -15.4559 - val_accuracy: 0.6533
# Epoch 259/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6151 - accuracy: 0.6396 - val_loss: -15.4590 - val_accuracy: 0.6667
# Epoch 260/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6225 - accuracy: 0.6532 - val_loss: -15.4629 - val_accuracy: 0.6667
# Epoch 261/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6254 - accuracy: 0.6441 - val_loss: -15.4634 - val_accuracy: 0.6667
# Epoch 262/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6260 - accuracy: 0.6532 - val_loss: -15.4651 - val_accuracy: 0.6667
# Epoch 263/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6323 - accuracy: 0.6532 - val_loss: -15.4696 - val_accuracy: 0.6667
# Epoch 264/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6361 - accuracy: 0.6396 - val_loss: -15.4727 - val_accuracy: 0.6533
# Epoch 265/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.6439 - accuracy: 0.6396 - val_loss: -15.4748 - val_accuracy: 0.6667
# Epoch 266/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6464 - accuracy: 0.6532 - val_loss: -15.4804 - val_accuracy: 0.6667
# Epoch 267/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6503 - accuracy: 0.6532 - val_loss: -15.4795 - val_accuracy: 0.6667
# Epoch 268/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6542 - accuracy: 0.6532 - val_loss: -15.4833 - val_accuracy: 0.6667
# Epoch 269/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6580 - accuracy: 0.6486 - val_loss: -15.4864 - val_accuracy: 0.6533
# Epoch 270/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6616 - accuracy: 0.6396 - val_loss: -15.4802 - val_accuracy: 0.6533
# Epoch 271/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.6646 - accuracy: 0.6396 - val_loss: -15.4839 - val_accuracy: 0.6667
# Epoch 272/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6750 - accuracy: 0.6532 - val_loss: -15.4918 - val_accuracy: 0.6667
# Epoch 273/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6811 - accuracy: 0.6532 - val_loss: -15.5005 - val_accuracy: 0.6667
# Epoch 274/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6853 - accuracy: 0.6532 - val_loss: -15.5053 - val_accuracy: 0.6667
# Epoch 275/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.6885 - accuracy: 0.6441 - val_loss: -15.5122 - val_accuracy: 0.6667
# Epoch 276/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.6938 - accuracy: 0.6532 - val_loss: -15.5158 - val_accuracy: 0.6667
# Epoch 277/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.6995 - accuracy: 0.6532 - val_loss: -15.5143 - val_accuracy: 0.6667
# Epoch 278/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7030 - accuracy: 0.6486 - val_loss: -15.5169 - val_accuracy: 0.6533
# Epoch 279/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7080 - accuracy: 0.6486 - val_loss: -15.5284 - val_accuracy: 0.6667
# Epoch 280/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7170 - accuracy: 0.6532 - val_loss: -15.5349 - val_accuracy: 0.6667
# Epoch 281/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7210 - accuracy: 0.6532 - val_loss: -15.5373 - val_accuracy: 0.6667
# Epoch 282/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7248 - accuracy: 0.6532 - val_loss: -15.5399 - val_accuracy: 0.6533
# Epoch 283/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7302 - accuracy: 0.6396 - val_loss: -15.5429 - val_accuracy: 0.6667
# Epoch 284/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7388 - accuracy: 0.6532 - val_loss: -15.5506 - val_accuracy: 0.6667
# Epoch 285/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7441 - accuracy: 0.6532 - val_loss: -15.5533 - val_accuracy: 0.6667
# Epoch 286/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7476 - accuracy: 0.6441 - val_loss: -15.5554 - val_accuracy: 0.6667
# Epoch 287/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7512 - accuracy: 0.6532 - val_loss: -15.5570 - val_accuracy: 0.6667
# Epoch 288/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7559 - accuracy: 0.6532 - val_loss: -15.5653 - val_accuracy: 0.6667
# Epoch 289/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7646 - accuracy: 0.6532 - val_loss: -15.5680 - val_accuracy: 0.6533
# Epoch 290/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7688 - accuracy: 0.6396 - val_loss: -15.5705 - val_accuracy: 0.6667
# Epoch 291/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.7719 - accuracy: 0.6532 - val_loss: -15.5736 - val_accuracy: 0.6667
# Epoch 292/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7758 - accuracy: 0.6532 - val_loss: -15.5771 - val_accuracy: 0.6667
# Epoch 293/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7802 - accuracy: 0.6532 - val_loss: -15.5810 - val_accuracy: 0.6533
# Epoch 294/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7835 - accuracy: 0.6441 - val_loss: -15.5852 - val_accuracy: 0.6667
# Epoch 295/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7868 - accuracy: 0.6532 - val_loss: -15.5864 - val_accuracy: 0.6667
# Epoch 296/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7893 - accuracy: 0.6532 - val_loss: -15.5894 - val_accuracy: 0.6667
# Epoch 297/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7920 - accuracy: 0.6486 - val_loss: -15.5927 - val_accuracy: 0.6667
# Epoch 298/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.7958 - accuracy: 0.6486 - val_loss: -15.5985 - val_accuracy: 0.6667
# Epoch 299/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.7986 - accuracy: 0.6532 - val_loss: -15.6002 - val_accuracy: 0.6667
# Epoch 300/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8015 - accuracy: 0.6532 - val_loss: -15.6021 - val_accuracy: 0.6667
# Epoch 301/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8054 - accuracy: 0.6532 - val_loss: -15.6061 - val_accuracy: 0.6667
# Epoch 302/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8092 - accuracy: 0.6532 - val_loss: -15.6092 - val_accuracy: 0.6667
# Epoch 303/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.8126 - accuracy: 0.6532 - val_loss: -15.6131 - val_accuracy: 0.6533
# Epoch 304/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.8162 - accuracy: 0.6396 - val_loss: -15.6146 - val_accuracy: 0.6667
# Epoch 305/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.8207 - accuracy: 0.6532 - val_loss: -15.6179 - val_accuracy: 0.6667
# Epoch 306/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8260 - accuracy: 0.6532 - val_loss: -15.6277 - val_accuracy: 0.6667
# Epoch 307/500
# 5/5 [==============================] - 0s 9ms/step - loss: -15.8364 - accuracy: 0.6532 - val_loss: -15.6312 - val_accuracy: 0.6667
# Epoch 308/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8391 - accuracy: 0.6532 - val_loss: -15.6345 - val_accuracy: 0.6667
# Epoch 309/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8439 - accuracy: 0.6532 - val_loss: -15.6381 - val_accuracy: 0.6533
# Epoch 310/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8473 - accuracy: 0.6441 - val_loss: -15.6417 - val_accuracy: 0.6667
# Epoch 311/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8532 - accuracy: 0.6532 - val_loss: -15.6525 - val_accuracy: 0.6667
# Epoch 312/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8581 - accuracy: 0.6532 - val_loss: -15.6560 - val_accuracy: 0.6667
# Epoch 313/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8614 - accuracy: 0.6532 - val_loss: -15.6578 - val_accuracy: 0.6667
# Epoch 314/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8640 - accuracy: 0.6532 - val_loss: -15.6613 - val_accuracy: 0.6667
# Epoch 315/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8666 - accuracy: 0.6532 - val_loss: -15.6633 - val_accuracy: 0.6667
# Epoch 316/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8694 - accuracy: 0.6532 - val_loss: -15.6680 - val_accuracy: 0.6533
# Epoch 317/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8733 - accuracy: 0.6441 - val_loss: -15.6690 - val_accuracy: 0.6667
# Epoch 318/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8776 - accuracy: 0.6532 - val_loss: -15.6715 - val_accuracy: 0.6667
# Epoch 319/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8781 - accuracy: 0.6532 - val_loss: -15.6671 - val_accuracy: 0.6667
# Epoch 320/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.8829 - accuracy: 0.6532 - val_loss: -15.6768 - val_accuracy: 0.6667
# Epoch 321/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8868 - accuracy: 0.6532 - val_loss: -15.6788 - val_accuracy: 0.6667
# Epoch 322/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8901 - accuracy: 0.6532 - val_loss: -15.6822 - val_accuracy: 0.6667
# Epoch 323/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8934 - accuracy: 0.6441 - val_loss: -15.6850 - val_accuracy: 0.6667
# Epoch 324/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8964 - accuracy: 0.6532 - val_loss: -15.6891 - val_accuracy: 0.6667
# Epoch 325/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.9003 - accuracy: 0.6532 - val_loss: -15.6844 - val_accuracy: 0.6667
# Epoch 326/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.8986 - accuracy: 0.6532 - val_loss: -15.6869 - val_accuracy: 0.6667
# Epoch 327/500
# 5/5 [==============================] - 0s 6ms/step - loss: -15.9024 - accuracy: 0.6532 - val_loss: -15.6903 - val_accuracy: 0.6533
# Epoch 328/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.9072 - accuracy: 0.6486 - val_loss: -15.6927 - val_accuracy: 0.6667
# Epoch 329/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.9101 - accuracy: 0.6486 - val_loss: -15.7032 - val_accuracy: 0.6667
# Epoch 330/500
# 5/5 [==============================] - 0s 8ms/step - loss: -15.9182 - accuracy: 0.6532 - val_loss: -15.7173 - val_accuracy: 0.6667
# Epoch 331/500
# 5/5 [==============================] - 0s 7ms/step - loss: -15.9341 - accuracy: 0.6532 - val_loss: -15.7220 - val_accuracy: 0.6667
# Epoch 332/500
# ...
# Epoch 391/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1174 - accuracy: 0.6532 - val_loss: -15.9239 - val_accuracy: 0.6667
# Epoch 392/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1198 - accuracy: 0.6532 - val_loss: -15.9170 - val_accuracy: 0.6667
# Epoch 393/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1233 - accuracy: 0.6532 - val_loss: -15.9234 - val_accuracy: 0.6533
# Epoch 394/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1267 - accuracy: 0.6396 - val_loss: -15.9235 - val_accuracy: 0.6667
# Epoch 395/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1296 - accuracy: 0.6532 - val_loss: -15.9408 - val_accuracy: 0.6667
# Epoch 396/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1329 - accuracy: 0.6532 - val_loss: -15.9325 - val_accuracy: 0.6667
# Epoch 397/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1354 - accuracy: 0.6532 - val_loss: -15.9294 - val_accuracy: 0.6667
# Epoch 398/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1379 - accuracy: 0.6532 - val_loss: -15.9340 - val_accuracy: 0.6667
# Epoch 399/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1405 - accuracy: 0.6532 - val_loss: -15.9361 - val_accuracy: 0.6667
# Epoch 400/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1443 - accuracy: 0.6532 - val_loss: -15.9461 - val_accuracy: 0.6667
# Epoch 401/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1482 - accuracy: 0.6486 - val_loss: -15.9456 - val_accuracy: 0.6533
# Epoch 402/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1514 - accuracy: 0.6396 - val_loss: -15.9468 - val_accuracy: 0.6667
# Epoch 403/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1544 - accuracy: 0.6532 - val_loss: -15.9485 - val_accuracy: 0.6667
# Epoch 404/500
# 5/5 [==============================] - 0s 8ms/step - loss: -16.1578 - accuracy: 0.6532 - val_loss: -15.9561 - val_accuracy: 0.6667
# Epoch 405/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1609 - accuracy: 0.6532 - val_loss: -15.9618 - val_accuracy: 0.6667
# Epoch 406/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1637 - accuracy: 0.6441 - val_loss: -15.9619 - val_accuracy: 0.6667
# Epoch 407/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1654 - accuracy: 0.6532 - val_loss: -15.9646 - val_accuracy: 0.6533
# Epoch 408/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1684 - accuracy: 0.6396 - val_loss: -15.9685 - val_accuracy: 0.6667
# Epoch 409/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1711 - accuracy: 0.6532 - val_loss: -15.9704 - val_accuracy: 0.6667
# Epoch 410/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1742 - accuracy: 0.6532 - val_loss: -15.9699 - val_accuracy: 0.6667
# Epoch 411/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1777 - accuracy: 0.6532 - val_loss: -15.9763 - val_accuracy: 0.6533
# Epoch 412/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1798 - accuracy: 0.6441 - val_loss: -15.9784 - val_accuracy: 0.6667
# Epoch 413/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1828 - accuracy: 0.6532 - val_loss: -15.9825 - val_accuracy: 0.6533
# Epoch 414/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1853 - accuracy: 0.6396 - val_loss: -15.9856 - val_accuracy: 0.6667
# Epoch 415/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1889 - accuracy: 0.6532 - val_loss: -15.9874 - val_accuracy: 0.6667
# Epoch 416/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.1919 - accuracy: 0.6532 - val_loss: -15.9894 - val_accuracy: 0.6667
# Epoch 417/500
# 5/5 [==============================] - 0s 8ms/step - loss: -16.1941 - accuracy: 0.6532 - val_loss: -15.9946 - val_accuracy: 0.6667
# Epoch 418/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.1971 - accuracy: 0.6532 - val_loss: -15.9958 - val_accuracy: 0.6667
# Epoch 419/500
# 5/5 [==============================] - 0s 8ms/step - loss: -16.2002 - accuracy: 0.6532 - val_loss: -16.0019 - val_accuracy: 0.6667
# Epoch 420/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2031 - accuracy: 0.6441 - val_loss: -16.0032 - val_accuracy: 0.6667
# Epoch 421/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2058 - accuracy: 0.6532 - val_loss: -16.0066 - val_accuracy: 0.6667
# Epoch 422/500
# 5/5 [==============================] - 0s 8ms/step - loss: -16.2089 - accuracy: 0.6532 - val_loss: -16.0079 - val_accuracy: 0.6533
# Epoch 423/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2109 - accuracy: 0.6396 - val_loss: -16.0124 - val_accuracy: 0.6533
# Epoch 424/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2133 - accuracy: 0.6486 - val_loss: -16.0149 - val_accuracy: 0.6667
# Epoch 425/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2156 - accuracy: 0.6532 - val_loss: -16.0175 - val_accuracy: 0.6667
# Epoch 426/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2178 - accuracy: 0.6532 - val_loss: -16.0204 - val_accuracy: 0.6667
# Epoch 427/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2203 - accuracy: 0.6532 - val_loss: -16.0247 - val_accuracy: 0.6667
# Epoch 428/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2226 - accuracy: 0.6532 - val_loss: -16.0304 - val_accuracy: 0.6667
# Epoch 429/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2252 - accuracy: 0.6486 - val_loss: -16.0311 - val_accuracy: 0.6667
# Epoch 430/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2280 - accuracy: 0.6532 - val_loss: -16.0351 - val_accuracy: 0.6667
# Epoch 431/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2394 - accuracy: 0.6532 - val_loss: -16.0539 - val_accuracy: 0.6667
# Epoch 432/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2450 - accuracy: 0.6532 - val_loss: -16.0500 - val_accuracy: 0.6667
# Epoch 433/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2417 - accuracy: 0.6532 - val_loss: -16.0414 - val_accuracy: 0.6533
# Epoch 434/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2399 - accuracy: 0.6396 - val_loss: -16.0456 - val_accuracy: 0.6667
# Epoch 435/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2444 - accuracy: 0.6532 - val_loss: -16.0625 - val_accuracy: 0.6667
# Epoch 436/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2566 - accuracy: 0.6396 - val_loss: -16.0683 - val_accuracy: 0.6667
# Epoch 437/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2593 - accuracy: 0.6532 - val_loss: -16.0682 - val_accuracy: 0.6667
# Epoch 438/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2616 - accuracy: 0.6532 - val_loss: -16.0579 - val_accuracy: 0.6667
# Epoch 439/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2570 - accuracy: 0.6532 - val_loss: -16.0634 - val_accuracy: 0.6667
# Epoch 440/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2579 - accuracy: 0.6532 - val_loss: -16.0589 - val_accuracy: 0.6667
# Epoch 441/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2646 - accuracy: 0.6532 - val_loss: -16.0807 - val_accuracy: 0.6667
# Epoch 442/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2720 - accuracy: 0.6441 - val_loss: -16.0688 - val_accuracy: 0.6533
# Epoch 443/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2683 - accuracy: 0.6396 - val_loss: -16.0687 - val_accuracy: 0.6667
# Epoch 444/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2686 - accuracy: 0.6532 - val_loss: -16.0762 - val_accuracy: 0.6667
# Epoch 445/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2778 - accuracy: 0.6532 - val_loss: -16.0896 - val_accuracy: 0.6667
# Epoch 446/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2822 - accuracy: 0.6532 - val_loss: -16.0900 - val_accuracy: 0.6667
# Epoch 447/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2881 - accuracy: 0.6532 - val_loss: -16.0956 - val_accuracy: 0.6667
# Epoch 448/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2913 - accuracy: 0.6532 - val_loss: -16.0945 - val_accuracy: 0.6533
# Epoch 449/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2847 - accuracy: 0.6306 - val_loss: -16.1021 - val_accuracy: 0.6667
# Epoch 450/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2945 - accuracy: 0.6532 - val_loss: -16.1009 - val_accuracy: 0.6667
# Epoch 451/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2939 - accuracy: 0.6532 - val_loss: -16.0947 - val_accuracy: 0.6667
# Epoch 452/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.2936 - accuracy: 0.6532 - val_loss: -16.0970 - val_accuracy: 0.6533
# Epoch 453/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.2937 - accuracy: 0.6351 - val_loss: -16.0952 - val_accuracy: 0.6667
# Epoch 454/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3030 - accuracy: 0.6532 - val_loss: -16.1191 - val_accuracy: 0.6667
# Epoch 455/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3104 - accuracy: 0.6532 - val_loss: -16.1214 - val_accuracy: 0.6667
# Epoch 456/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3131 - accuracy: 0.6486 - val_loss: -16.1222 - val_accuracy: 0.6533
# Epoch 457/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3160 - accuracy: 0.6351 - val_loss: -16.1301 - val_accuracy: 0.6667
# Epoch 458/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3188 - accuracy: 0.6441 - val_loss: -16.1292 - val_accuracy: 0.6667
# Epoch 459/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3222 - accuracy: 0.6532 - val_loss: -16.1265 - val_accuracy: 0.6667
# Epoch 460/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3235 - accuracy: 0.6532 - val_loss: -16.1380 - val_accuracy: 0.6667
# Epoch 461/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3188 - accuracy: 0.6532 - val_loss: -16.1435 - val_accuracy: 0.6667
# Epoch 462/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3304 - accuracy: 0.6532 - val_loss: -16.1452 - val_accuracy: 0.6533
# Epoch 463/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3329 - accuracy: 0.6396 - val_loss: -16.1504 - val_accuracy: 0.6667
# Epoch 464/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3345 - accuracy: 0.6441 - val_loss: -16.1488 - val_accuracy: 0.6667
# Epoch 465/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3379 - accuracy: 0.6532 - val_loss: -16.1631 - val_accuracy: 0.6667
# Epoch 466/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3395 - accuracy: 0.6532 - val_loss: -16.1447 - val_accuracy: 0.6667
# Epoch 467/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3369 - accuracy: 0.6532 - val_loss: -16.1710 - val_accuracy: 0.6667
# Epoch 468/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3453 - accuracy: 0.6532 - val_loss: -16.1589 - val_accuracy: 0.6533
# Epoch 469/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3487 - accuracy: 0.6396 - val_loss: -16.1749 - val_accuracy: 0.6533
# Epoch 470/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3515 - accuracy: 0.6441 - val_loss: -16.1796 - val_accuracy: 0.6667
# Epoch 471/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3545 - accuracy: 0.6532 - val_loss: -16.1693 - val_accuracy: 0.6667
# Epoch 472/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3576 - accuracy: 0.6532 - val_loss: -16.1740 - val_accuracy: 0.6667
# Epoch 473/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3549 - accuracy: 0.6532 - val_loss: -16.1792 - val_accuracy: 0.6667
# Epoch 474/500
# 5/5 [==============================] - 0s 8ms/step - loss: -16.3614 - accuracy: 0.6532 - val_loss: -16.1945 - val_accuracy: 0.6667
# Epoch 475/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3639 - accuracy: 0.6532 - val_loss: -16.1683 - val_accuracy: 0.6533
# Epoch 476/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3669 - accuracy: 0.6081 - val_loss: -16.1799 - val_accuracy: 0.6667
# Epoch 477/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3698 - accuracy: 0.6532 - val_loss: -16.1847 - val_accuracy: 0.6667
# Epoch 478/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3648 - accuracy: 0.6532 - val_loss: -16.1707 - val_accuracy: 0.6667
# Epoch 479/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3635 - accuracy: 0.6532 - val_loss: -16.1797 - val_accuracy: 0.6667
# Epoch 480/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3755 - accuracy: 0.6532 - val_loss: -16.1948 - val_accuracy: 0.6667
# Epoch 481/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3795 - accuracy: 0.6532 - val_loss: -16.2039 - val_accuracy: 0.6667
# Epoch 482/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3827 - accuracy: 0.6532 - val_loss: -16.2253 - val_accuracy: 0.6667
# Epoch 483/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3856 - accuracy: 0.6532 - val_loss: -16.2131 - val_accuracy: 0.6667
# Epoch 484/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3880 - accuracy: 0.6532 - val_loss: -16.2427 - val_accuracy: 0.6667
# Epoch 485/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.3904 - accuracy: 0.6532 - val_loss: -16.1939 - val_accuracy: 0.6667
# Epoch 486/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3925 - accuracy: 0.6532 - val_loss: -16.2082 - val_accuracy: 0.6667
# Epoch 487/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3958 - accuracy: 0.6532 - val_loss: -16.2231 - val_accuracy: 0.6667
# Epoch 488/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.3989 - accuracy: 0.6486 - val_loss: -16.2536 - val_accuracy: 0.6533
# Epoch 489/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4013 - accuracy: 0.6351 - val_loss: -16.2439 - val_accuracy: 0.6667
# Epoch 490/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.4036 - accuracy: 0.6532 - val_loss: -16.2417 - val_accuracy: 0.6667
# Epoch 491/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4060 - accuracy: 0.6532 - val_loss: -16.2370 - val_accuracy: 0.6667
# Epoch 492/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.4077 - accuracy: 0.6532 - val_loss: -16.2659 - val_accuracy: 0.6667
# Epoch 493/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4104 - accuracy: 0.6532 - val_loss: -16.2234 - val_accuracy: 0.6667
# Epoch 494/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.4136 - accuracy: 0.6486 - val_loss: -16.2336 - val_accuracy: 0.6533
# Epoch 495/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4161 - accuracy: 0.6486 - val_loss: -16.2741 - val_accuracy: 0.6667
# Epoch 496/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.4187 - accuracy: 0.6532 - val_loss: -16.2542 - val_accuracy: 0.6667
# Epoch 497/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4216 - accuracy: 0.6532 - val_loss: -16.2695 - val_accuracy: 0.6667
# Epoch 498/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4250 - accuracy: 0.6532 - val_loss: -16.2766 - val_accuracy: 0.6533
# Epoch 499/500
# 5/5 [==============================] - 0s 7ms/step - loss: -16.4272 - accuracy: 0.6261 - val_loss: -16.2709 - val_accuracy: 0.6667
# Epoch 500/500
# 5/5 [==============================] - 0s 6ms/step - loss: -16.4303 - accuracy: 0.6532 - val_loss: -16.2521 - val_accuracy: 0.6667

# %%
# зауважте, що час виконання залежно від версії або типу обладнання може суттєво відрізнятися
# час виконання на першій ітерації під відеокартою зазвичай вищий, ніж на наступних

# %%
#Because latent space is two-dimensional, there are a few visualizations that can be done at this point. 
#One is to look at the neighborhoods of different classes on the latent 2D plane:
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(valid_y) + 1))))

start_time = time.time()
x_train_encoded = encoder.predict(train_x, batch_size=500)
plt.figure(figsize=(6, 6))
plt.scatter(x_train_encoded[:, 0], x_train_encoded[:, 1], c = colors[train_y])
plt.colorbar()
plt.show()

x_test_encoded = encoder.predict(valid_x, batch_size=500)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c = colors[valid_y])
plt.colorbar()
plt.show()
end_time = time.time()
# Out:
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 12ms/step

# %%
start_time = time.time()
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(ab, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.0011949539184570312

# %%
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler
start_time = time.time()
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X_embedded, y_pred)
end_time = time.time()
end_time-start_time
# Out:
# 0.0008537769317626953

# %%
colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']), int(max(y_pred) + 1))))

plt.figure(figsize=(6, 6))
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], s=2, c=colors[y_pred])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], s=2, c=colors[y_resampled])
plt.colorbar()
plt.show()

# %%
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(X_resampled, y_resampled)

# %%
#X_resampled, y_resampled = ros.fit_resample(X_embedded, y_pred)

# %%
from imblearn.over_sampling import SMOTE, ADASYN
start_time = time.time()
X_resampled2, y_resampled2 = SMOTE().fit_resample(X_embedded, y_pred)
#print(sorted(Counter(y_resampled).items()))
end_time = time.time()
end_time-start_time
# Out:
# 0.0029015541076660156

# %%
start_time = time.time()
clf_smote = LinearSVC().fit(X_resampled2, y_resampled2)
end_time = time.time()
end_time-start_time
# Out:
# /home/vlads/miniconda3/envs/tf2/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/vlads/miniconda3/envs/tf2/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.01255488395690918

# %%
start_time = time.time()
X_resampled3, y_resampled3 = ADASYN().fit_resample(X_embedded, y_pred)
#print(sorted(Counter(y_resampled).items()))
end_time = time.time()
end_time-start_time
# Out:
# 0.010250329971313477

# %%
start_time = time.time()
clf_adasyn = LinearSVC().fit(X_resampled3, y_resampled3)
end_time = time.time()
end_time-start_time
# Out:
# /home/vlads/miniconda3/envs/tf2/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/vlads/miniconda3/envs/tf2/lib/python3.11/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.012342214584350586

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X_resampled[:, 0], X_resampled[:, 1], s=2, c=colors[y_resampled])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled2[:, 0], X_resampled2[:, 1], s=2, c=colors[y_resampled2])
plt.colorbar()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(X_resampled3[:, 0], X_resampled3[:, 1], s=2, c=colors[y_resampled3])
plt.colorbar()
plt.show()

# %%
# stops here
